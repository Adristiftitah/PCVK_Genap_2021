# %% [markdown]
# <a href="https://colab.research.google.com/github/Adristiftitah/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/dogcute01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/dogcute01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#simpan file image

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(155,155,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],
                     [200,200],
                     [400,300],
                     [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/dogcute01.jpg')
plt.imshow(img)

# %%
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
# TUGAS NO 3 baris ke 10-100 ,kolom 10-100
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
# TUGAS NO 4  image baris ke 5-30
 
plt.imshow(img[5:30])

# %%
img_ktk = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_ktk, pt1=(300,200), pt2=(40,170), color=(0,255,0), thickness=10)
cv.rectangle(img_ktk, pt1=(354,0), pt2=(510,150), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(250,500), pt2=(510,150), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(350,750), pt2=(510,150), color=(0,255,0),thickness=10)
cv.rectangle(img_ktk, pt1=(500,700), pt2=(600,550), color=(0,255,0),thickness=10)
plt.imshow(img_ktk)

# %%
# TUGAS NO 6 GAMBAR TERBALIK 
img_tb = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)
 
#simpan file image
 
#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.imshow(img_tb)

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/image.jpg')
img = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
cv.rectangle(img,pt1=(680,680),pt2=(800,800),color=(0,0,255),thickness=15)
plt.imshow(img)

cv.circle(img,center=(750,750),radius=50,color=(255,0,0),thickness=8)
plt.imshow(img)

# %%
cv.rectangle(img,pt1=(200,1000),pt2=(10,1210),color=(0,255,0),thickness=10)
plt.imshow(img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(img,text='Adristi Y',org=(10,500),fontFace=font,fontScale=4,color=(0,255,255),thickness=2,lineType=cv.LINE_AA)
plt.imshow(img)
